# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavjha06/vibhunotes/blob/main/pandasclassvibhu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot
# math plotting library

# %matplotlib inline

# import the mockaroo file
mock_data = pd.read_csv("MOCK_DATA.csv")

mock_data.info()

mock_data.index
mock_data.head(3)

mock_data.loc[0]
mock_data.describe()
mock_data.columns

mock_data.dtypes

mock_data = mock_data.rename(columns={'first_name': 'fname', 'last_name': 'lname'})
mock_data['fname']

pd.value_counts(mock_data['gender']).plot.bar()
mock_data.groupby(['gender'])['age'].mean()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   ip_address  1000 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-2bc64452f26a> in <cell line: 26>()
#      24
#      25 pd.value_counts(mock_data['gender']).plot.bar()
# ---> 26 mock_data.groupby(['gender'])['age'].mean()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1414                 stacklevel=find_stack_level(),
# ...
